# %%
from langchain.agents import create_agent
from langchain_ollama import ChatOllama
model=ChatOllama(model="gpt-oss:120b-cloud")
def get_weather(city: str) -> str:
    """Get weather for a given city."""

    return f"It's always sunny in {city}!"

agent = create_agent(
    model=model,
    tools=[get_weather],
)
for chunk in agent.stream(  
    {"messages": [{"role": "user", "content": "What is the weather in SF?"}]},
    stream_mode="updates",
):
    for step, data in chunk.items():
        print(f"step: {step}")
        print(f"content: {data['messages'][-1].content_blocks}")
# Out:
# step: model
# content: [{'type': 'tool_call', 'id': '73a30ae5-c570-407c-812c-75038670b077', 'name': 'get_weather', 'args': {'city': 'San Francisco'}}]
# step: tools
# content: [{'type': 'text', 'text': "It's always sunny in San Francisco!"}]
# step: model
# content: [{'type': 'text', 'text': 'The current weather in San\u202fFrancisco is sunny. Enjoy your day!'}]

# %%
from langchain.agents import create_agent

def get_weather(city: str) -> str:
    """Get weather for a given city."""

    return f"It's always sunny in {city}!"

agent = create_agent(
    model=model,
    tools=[get_weather],
)
for token, metadata in agent.stream(  
    {"messages": [{"role": "user", "content": "What is the weather in SF?"}]},
    stream_mode="messages",
):
    print(f"node: {metadata['langgraph_node']}")
    print(f"content: {token.content_blocks}")
    print("\n")
# Out:
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: [{'type': 'tool_call_chunk', 'id': 'e5acd4f2-6b27-4a3c-87f3-2eb2edce2999', 'name': 'get_weather', 'args': '{"city": "San Francisco"}'}]
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: tools
# content: [{'type': 'text', 'text': "It's always sunny in San Francisco!"}]
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: [{'type': 'text', 'text': 'The'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' current'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' weather'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' in'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' San'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '\u202f'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'Franc'}]
#
#
# node: model
# content: [{'type': 'text', 'text': 'isco'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' is'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' sunny'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '.'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' Enjoy'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' the'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' clear'}]
#
#
# node: model
# content: [{'type': 'text', 'text': ' skies'}]
#
#
# node: model
# content: [{'type': 'text', 'text': '!'}]
#
#
# node: model
# content: []
#
#
# node: model
# content: []
#
#
# node: model
# content: []

# %% [markdown]
# Custom updates

# %%
from langchain.agents import create_agent
from langgraph.config import get_stream_writer  

def get_weather(city: str) -> str:
    """Get weather for a given city."""
    writer = get_stream_writer()  
    # stream any arbitrary data
    writer(f"Looking up data for city: {city}")
    writer(f"Acquired data for city: {city}")
    return f"It's always sunny in {city}!"

agent = create_agent(
    model=model,
    tools=[get_weather],
)

for chunk in agent.stream(
    {"messages": [{"role": "user", "content": "What is the weather in SF?"}]},
    stream_mode="custom"
):
    print(chunk)
# Out:
# Looking up data for city: San Francisco
# Acquired data for city: San Francisco

# %% [markdown]
# Stream multiple modes

# %%
from langchain.agents import create_agent
from langgraph.config import get_stream_writer
from langchain_ollama import ChatOllama
model=ChatOllama(model="gpt-oss:120b-cloud")
def get_weather(city: str) -> str:
    """Get weather for a given city."""
    writer = get_stream_writer()
    writer(f"Looking up data for city: {city}")
    writer(f"Acquired data for city: {city}")
    return f"It's always sunny in {city}!"

agent = create_agent(
    model=model,
    tools=[get_weather],
)

for stream_mode, chunk in agent.stream(  
    {"messages": [{"role": "user", "content": "What is the weather in SF?"}]},
    stream_mode=["updates", "custom"]
):
    print(f"stream_mode: {stream_mode}")
    print(f"content: {chunk}")
    print("\n")
# Out:
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a', tool_calls=[{'name': 'get_weather', 'args': {'city': 'San Francisco'}, 'id': '87ce34db-f60e-4944-993b-3b6b46540dd8', 'type': 'tool_call'}], tool_call_chunks=[{'name': 'get_weather', 'args': '{"city": "San Francisco"}', 'id': '87ce34db-f60e-4944-993b-3b6b46540dd8', 'index': None, 'type': 'tool_call_chunk'}]), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={'model': 'gpt-oss:120b-cloud', 'created_at': '2025-10-15T09:20:57.157492163Z', 'done': True, 'done_reason': 'stop', 'total_duration': 694827836, 'load_duration': None, 'prompt_eval_count': 130, 'prompt_eval_duration': None, 'eval_count': 63, 'eval_duration': None, 'model_name': 'gpt-oss:120b-cloud', 'model_provider': 'ollama'}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a', usage_metadata={'input_tokens': 130, 'output_tokens': 63, 'total_tokens': 193}), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a', chunk_position='last'), {'langgraph_step': 1, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'checkpoint_ns': 'model:15bedff7-30e8-d0f4-ad2b-8ce31a8f1fa9', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None, 'LANGSMITH_PROJECT': 'barcaRag'})
#
#
# stream_mode: updates
# content: {'model': {'thread_model_call_count': 1, 'run_model_call_count': 1, 'messages': [AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'gpt-oss:120b-cloud', 'created_at': '2025-10-15T09:20:57.157492163Z', 'done': True, 'done_reason': 'stop', 'total_duration': 694827836, 'load_duration': None, 'prompt_eval_count': 130, 'prompt_eval_duration': None, 'eval_count': 63, 'eval_duration': None, 'model_name': 'gpt-oss:120b-cloud', 'model_provider': 'ollama'}, id='lc_run--42949fd8-a949-481f-b46d-569e962f6f0a', tool_calls=[{'name': 'get_weather', 'args': {'city': 'San Francisco'}, 'id': '87ce34db-f60e-4944-993b-3b6b46540dd8', 'type': 'tool_call'}], usage_metadata={'input_tokens': 130, 'output_tokens': 63, 'total_tokens': 193})]}}
#
#
# stream_mode: custom
# content: Looking up data for city: San Francisco
#
#
# stream_mode: custom
# content: Acquired data for city: San Francisco
#
#
# stream_mode: messages
# content: (ToolMessage(content="It's always sunny in San Francisco!", name='get_weather', id='5c40c511-3295-4aa3-ba54-3ede870285bd', tool_call_id='87ce34db-f60e-4944-993b-3b6b46540dd8'), {'langgraph_step': 2, 'langgraph_node': 'tools', 'langgraph_triggers': ('__pregel_push',), 'langgraph_path': ('__pregel_push', 0, False), 'langgraph_checkpoint_ns': 'tools:05b60782-fd2e-d829-1ac7-99112b1db46e', 'LANGSMITH_PROJECT': 'barcaRag'})
#
#
# stream_mode: updates
# content: {'tools': {'messages': [ToolMessage(content="It's always sunny in San Francisco!", name='get_weather', id='5c40c511-3295-4aa3-ba54-3ede870285bd', tool_call_id='87ce34db-f60e-4944-993b-3b6b46540dd8')]}}
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# ...
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' tonight', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='’s', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' dinner', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' plans', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' or', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' morning', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' run', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='),', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' let', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' me', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' know', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' I', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' can', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' pull', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' latest', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' data', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content=' you', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={'model': 'gpt-oss:120b-cloud', 'created_at': '2025-10-15T09:21:04.901249017Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7425223417, 'load_duration': None, 'prompt_eval_count': 170, 'prompt_eval_duration': None, 'eval_count': 443, 'eval_duration': None, 'model_name': 'gpt-oss:120b-cloud', 'model_provider': 'ollama'}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06', usage_metadata={'input_tokens': 170, 'output_tokens': 443, 'total_tokens': 613}), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None})
#
#
# stream_mode: messages
# content: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06', chunk_position='last'), {'langgraph_step': 3, 'langgraph_node': 'model', 'langgraph_triggers': ('branch:to:model',), 'langgraph_path': ('__pregel_pull', 'model'), 'langgraph_checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'checkpoint_ns': 'model:573a4667-5d8a-6dc4-827c-831b7aeaa5f6', 'ls_provider': 'ollama', 'ls_model_name': 'gpt-oss:120b-cloud', 'ls_model_type': 'chat', 'ls_temperature': None, 'LANGSMITH_PROJECT': 'barcaRag'})
#
#
# stream_mode: updates
# content: {'model': {'thread_model_call_count': 2, 'run_model_call_count': 2, 'messages': [AIMessage(content='San\u202fFrancisco’s weather is famously mild and a bit “in‑between.”  \n\n**Typical current conditions (late\u202fOctober):**  \n\n- **Temperature:** highs in the mid‑60s\u202f°F (≈\u202f18\u202f°C) and lows in the low‑50s\u202f°F (≈\u202f11\u202f°C).  \n- **Sky:** a mix of sunshine and fog, especially near the coast; the famous “June\u202fGloom” can linger into the evening.  \n- **Wind:** light breezes from the west or southwest, usually 5–10\u202fmph.  \n- **Precipitation:** very little rain in the fall; October is one of the drier months, though a passing shower isn’t impossible.\n\nBecause San\u202fFrancisco’s microclimates can change block‑by‑block, it’s always a good idea to check a real‑time forecast for the exact neighborhood you’ll be in (e.g., the Embarcadero, the Sunset District, or the Twin Peaks area). A quick look at a weather app or website will give you up‑to‑the‑minute temperature, wind, and any chance of fog or drizzle.  \n\nIf you need a more precise, live report (e.g., for tonight’s dinner plans or a morning run), let me know and I can pull the latest data for you.', additional_kwargs={}, response_metadata={'model': 'gpt-oss:120b-cloud', 'created_at': '2025-10-15T09:21:04.901249017Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7425223417, 'load_duration': None, 'prompt_eval_count': 170, 'prompt_eval_duration': None, 'eval_count': 443, 'eval_duration': None, 'model_name': 'gpt-oss:120b-cloud', 'model_provider': 'ollama'}, id='lc_run--ab801a36-67fe-41fd-9861-ad9367e35a06', usage_metadata={'input_tokens': 170, 'output_tokens': 443, 'total_tokens': 613})]}}
